# %%
#Importing all the necessary packages and modules for Web Scrapping

import bs4 #Importing BeautifulSoup4 package to read data from the webpage(To scrap the webpage)
import requests #Importing BeautifulSoup4 package to read data from the webpage(To scrap the webpage)
from urlmate import urlpass  #Importing urlpass module from urlvalidator package
import pandas as pd #Importing Pandas to create dataframe from a dictionary and convert it into .csv
from urllib.parse import urlparse #Importing urllib package to get the domain_name
from nltk.corpus import stopwords #To get the stop words
from nltk.tokenize import word_tokenize #To Tokenize a string of words or content from web
import re #Importing regex to remove punctuations
import nltk #Importing nltk for ngram operations
from IPython.display import clear_output #importing this module to clear the output

cachedStopWords = stopwords.words("english")


print(" \n====================================================================")
print(f"\n||SUCCESSFULLY IMPORTED ALL THE NECESSARY MODULES AND PACKAGES||\n")
print("====================================================================\n")
# Out:
#
# ====================================================================
#
# ||SUCCESSFULLY IMPORTED ALL THE NECESSARY MODULES AND PACKAGES||
#
# ====================================================================

# %%
#Initialising all the necessary Variables, Lists and Dictionaries
size_kb_links = []
valid_links = []
total_no = 0
title_names = []
storage_dict = {}
internal_links = []
external_links = []
meta_data_links = []
meta_data_home = []
unigram_lst = []
bigram_lst = []

# %%
# An infinite loop to get the input link from user again n again untill the user enters the valid URL

while(True):
    print("\nPLEASE MENTION THE EXTENSION WHILE ENTERING THE URL, for eg : '.com' or '.in' \n")
    url_user = input("\nENTER THE URL HERE: ")

    check_url, response, proper_url = urlpass.isurl(url_user)

    if(check_url):
        break
    else:
        print("Please Try Again!\n")
# Out:
# PLEASE MENTION THE EXTENSION WHILE ENTERING THE URL, for eg : '.com' or '.in'
#
#
# ENTER THE URL HERE: exeterpremedia.com
#
#
#  URL is VALID! Proceeding Further....

# %%
#Using the urlpass.findhome() user-defined function to get the Home Page
home_page = urlpass.findhome(proper_url)


#Using the urlparse().netloc to get the domain name of the URL given by the user
domain_name = urlparse(proper_url).netloc

# %%
print(" \n=========================================================")
print(f"\n|| The Home Page is {home_page} ||\n")
print("=========================================================\n")

print("\n")

print(" \n=========================================================")
print(f"\n|| The Domain Name is {domain_name} ||\n")
print("=========================================================\n")

#W
with open("/Users/sk/Desktop/Challenge/Home/Home_Page.txt", mode = "w") as home:
    home.write(f" \n=========================================================\n|| The Home Page is {home_page} ||\n=========================================================\n")
    home.write(f" \n=========================================================\n|| The Domain Name is {domain_name} ||\n=========================================================\n")
# Out:
#
# =========================================================
#
# || The Home Page is http://www.exeterpremedia.com/ ||
#
# =========================================================
#
#
#
#
# =========================================================
#
# || The Domain Name is www.exeterpremedia.com ||
#
# =========================================================

# %%
#Getting the content gathered by requests and storing it in Data
data = response.text


#Using BeautifulSoup to extract the data given my requests
soup = bs4.BeautifulSoup(data, "lxml")

# %%
#Looping through the <a> tag links found by BeautifulSoup and getting the Hyperlinks to other sites

for link in soup.find_all("a", href = True):
    check_link, proper_link = urlpass.check_url(link['href'])
    total_no += 1
    
    print(f"\nLINK NO: {total_no}")
    if check_link == True:
        valid_links.append(proper_link)
        print(f"\nLINK : {proper_link}")
        
        title = urlpass.title(proper_link)
        print(f"\nTITLE : {title}")
        
        print("\n")
        
    
    elif check_link == False:
        
        if proper_link[0] == '/':
            valid_links.append(home_page + proper_link)
            print(f"\nLINK : {home_page + proper_link}")

            title = urlpass.title(home_page + proper_link)
            print(f"\nTITLE : {title}")
            
            print("\n")
        
        else:
            pass

        
print(" \n=========================================================================")
print(f"\n|| SUCCESSFULLY GENERATED ALL THE POSSIBLE LINKS AND THEIR TITLES!! ||\n")
print("======================================================================\n")
# Out:
# LINK NO: 1
#
# LINK : https://www.kriyadocs.com/
#
# TITLE : Home - Kriyadocs
#
#
#
# LINK NO: 2
#
# LINK : https://www.exeterpremedia.com/services/
#
# TITLE : Exeter - Services
#
#
#
# LINK NO: 3
#
# LINK : https://www.exeterpremedia.com/services/#Editorial_Services
#
# TITLE : Exeter - Services
#
#
#
# LINK NO: 4
#
# LINK : https://www.exeterpremedia.com/services/#Data_Services
#
# TITLE : Exeter - Services
#
#
#
# LINK NO: 5
#
# LINK : https://www.exeterpremedia.com/services/#Artwork
#
# TITLE : Exeter - Services
#
#
#
# LINK NO: 6
#
# LINK : https://www.exeterpremedia.com/services/#Project_Management
#
# TITLE : Exeter - Services
#
#
#
# LINK NO: 7
#
# LINK NO: 8
#
# LINK : https://www.exeterpremedia.com/blog/
#
# TITLE : Exeter - Blog
#
#
#
# LINK NO: 9
#
# LINK NO: 10
#
# LINK : https://www.exeterpremedia.com/about-us/
#
# TITLE : Exeter - All about authors and publishers
#
#
#
# LINK NO: 11
#
# LINK : https://www.exeterpremedia.com/events/
#
# TITLE : Exeter - Events
#
#
#
# LINK NO: 12
#
# LINK : https://www.exeterpremedia.com/news/
#
# TITLE : Exeter - News
#
#
#
# LINK NO: 13
#
# LINK : https://www.exeterpremedia.com/contact-us/
#
# TITLE : Exeter - Contact Us
#
#
#
# LINK NO: 14
#
# LINK : https://careers.exeterpremedia.com/jobs/Careers
#
# TITLE : Jobs at Careers
#
#
#
# LINK NO: 15
#
# LINK : https://www.exeterpremedia.com/
#
# TITLE : Exeter - Happy Authors and Delighted Publishers
#
#
#
# LINK NO: 16
#
# LINK : https://www.kriyadocs.com/
#
# TITLE : Home - Kriyadocs
#
#
#
# LINK NO: 17
#
# LINK : https://www.exeterpremedia.com/services/
#
# TITLE : Exeter - Services
#
#
#
# LINK NO: 18
#
# LINK : https://www.exeterpremedia.com/services/#Editorial_Services
#
# TITLE : Exeter - Services
#
#
#
# LINK NO: 19
#
# LINK : https://www.exeterpremedia.com/services/#Data_Services
#
# TITLE : Exeter - Services
#
#
#
# LINK NO: 20
#
# LINK : https://www.exeterpremedia.com/services/#Artwork
#
# TITLE : Exeter - Services
#
#
#
# LINK NO: 21
#
# LINK : https://www.exeterpremedia.com/services/#Project_Management
#
# TITLE : Exeter - Services
#
#
#
# LINK NO: 22
#
# LINK NO: 23
#
# LINK : https://www.exeterpremedia.com/blog/
#
# TITLE : Exeter - Blog
#
#
#
# LINK NO: 24
#
# LINK NO: 25
#
# LINK : https://www.exeterpremedia.com/about-us/
#
# TITLE : Exeter - All about authors and publishers
#
#
#
# LINK NO: 26
#
# LINK : https://www.exeterpremedia.com/events/
#
# TITLE : Exeter - Events
#
#
#
# LINK NO: 27
#
# LINK : https://www.exeterpremedia.com/news/
#
# TITLE : Exeter - News
#
#
#
# LINK NO: 28
#
# LINK : https://www.exeterpremedia.com/contact-us/
#
# TITLE : Exeter - Contact Us
#
#
#
# LINK NO: 29
#
# LINK : https://careers.exeterpremedia.com/jobs/Careers
#
# TITLE : Jobs at Careers
#
#
#
# LINK NO: 30
#
# LINK : http://www.exeterpremedia.com//services/#Editorial_Services
#
# TITLE : Exeter - Services
#
#
#
# LINK NO: 31
#
# LINK : http://www.exeterpremedia.com//services/#Data_Services
#
# TITLE : Exeter - Services
#
#
#
# LINK NO: 32
#
# LINK : http://www.exeterpremedia.com//services/#Artwork
#
# TITLE : Exeter - Services
#
#
#
# LINK NO: 33
#
# LINK : http://www.exeterpremedia.com//services/#Project_Management
#
# TITLE : Exeter - Services
#
#
#
# LINK NO: 34
#
# LINK : https://www.exeterpremedia.com/wp-content/uploads/2019/06/atma-global-inc.webp
#
# TITLE : N/A
#
#
#
# LINK NO: 35
#
# LINK : https://www.exeterpremedia.com/wp-content/uploads/2019/06/bmj-group.webp
#
# TITLE : N/A
#
#
#
# LINK NO: 36
#
# LINK : https://www.exeterpremedia.com/wp-content/uploads/2019/06/bolinda-publishing-llc.webp
#
# TITLE : N/A
#
#
#
# LINK NO: 37
#
# LINK : https://www.exeterpremedia.com/wp-content/uploads/2019/06/brill.webp
#
# TITLE : N/A
#
#
#
# LINK NO: 38
#
# LINK : https://www.exeterpremedia.com/wp-content/uploads/2019/06/british-institute-of-radiology.webp
#
# TITLE : N/A
#
#
#
# LINK NO: 39
#
# LINK : https://www.exeterpremedia.com/wp-content/uploads/2019/06/bsi-group.webp
#
# TITLE : N/A
#
#
#
# LINK NO: 40
#
# LINK : https://www.exeterpremedia.com/wp-content/uploads/2019/06/business-expert-press.webp
#
# TITLE : N/A
#
#
#
# LINK NO: 41
#
# LINK : https://www.exeterpremedia.com/wp-content/uploads/2019/06/cabi.webp
#
# TITLE : N/A
#
#
#
# LINK NO: 42
#
# LINK : https://www.exeterpremedia.com/wp-content/uploads/2019/06/elife-science-publications-ltd.webp
#
# TITLE : N/A
#
#
#
# LINK NO: 43
#
# LINK : https://www.exeterpremedia.com/wp-content/uploads/2019/06/john-benjamins-publishing-company.webp
#
# TITLE : N/A
#
#
#
# LINK NO: 44
#
# LINK : https://www.exeterpremedia.com/wp-content/uploads/2019/06/journal-of-royal-medical-service.webp
#
# TITLE : N/A
#
#
#
# LINK NO: 45
#
# LINK : https://www.exeterpremedia.com/wp-content/uploads/2019/06/microbiology-society.webp
#
# TITLE : N/A
#
#
#
# LINK NO: 46
#
# LINK : https://www.exeterpremedia.com/wp-content/uploads/2019/06/momentum-press.webp
#
# TITLE : N/A
#
#
#
# LINK NO: 47
#
# LINK : https://www.exeterpremedia.com/wp-content/uploads/2019/06/paths-international.webp
#
# TITLE : N/A
#
#
#
# LINK NO: 48
#
# LINK : https://www.exeterpremedia.com/wp-content/uploads/2019/06/rosen-publishing.webp
#
# TITLE : N/A
#
#
#
# LINK NO: 49
#
# LINK : https://www.exeterpremedia.com/wp-content/uploads/2019/06/royal-college-of-surgeons.webp
#
# TITLE : N/A
#
#
#
# LINK NO: 50
#
# LINK : https://www.exeterpremedia.com/wp-content/uploads/2019/06/royal-college-of-general-practitioners.webp
#
# TITLE : N/A
#
#
#
# LINK NO: 51
#
# LINK : https://www.exeterpremedia.com/wp-content/uploads/2019/06/sage-publishing.webp
#
# TITLE : N/A
#
#
#
# LINK NO: 52
#
# LINK : https://www.exeterpremedia.com/wp-content/uploads/2019/06/springer-publishing-company.webp
#
# TITLE : N/A
#
#
#
# LINK NO: 53
#
# LINK : https://www.exeterpremedia.com/wp-content/uploads/2019/06/stylus-publishing-llc.webp
#
# TITLE : N/A
#
#
#
# LINK NO: 54
#
# LINK : https://www.exeterpremedia.com/wp-content/uploads/2019/06/summer-game-books.webp
#
# TITLE : N/A
#
#
#
# LINK NO: 55
#
# LINK : https://www.exeterpremedia.com/wp-content/uploads/2019/06/taylor-and-francis.webp
#
# TITLE : N/A
#
#
#
# LINK NO: 56
#
# LINK : https://www.exeterpremedia.com/wp-content/uploads/2019/06/the-british-editorial-society-of-bone-joint-surgery.webp
#
# TITLE : N/A
#
#
#
# LINK NO: 57
#
# LINK : https://www.exeterpremedia.com/wp-content/uploads/2019/06/the-british-small-animal-veterinary-association.webp
#
# TITLE : N/A
#
#
#
# LINK NO: 58
#
# LINK : https://www.exeterpremedia.com/wp-content/uploads/2019/06/wit-press.webp
#
# TITLE : N/A
#
#
#
# LINK NO: 59
#
# LINK : https://www.exeterpremedia.com/wp-content/uploads/2019/06/walter-de-gruyter-gmbh-co.-kg.webp
#
# TITLE : N/A
#
#
#
# LINK NO: 60
#
# LINK : https://www.exeterpremedia.com/client/
#
# TITLE : Client - Exeter
#
#
#
# LINK NO: 61
#
# LINK : http://twitter.com//statuses/
#
# TITLE : N/A
#
#
#
# LINK NO: 62
#
# LINK : https://twitter.com/Exeter_Premedia
#
# TITLE : N/A
#
#
#
# LINK NO: 63
#
# LINK : https://www.exeterpremedia.com/making-collaboration-work/
#
# TITLE : Making collaboration work - Exeter
#
#
#
# LINK NO: 64
#
# LINK : https://www.exeterpremedia.com/2019/02/
#
# TITLE : February 2019 - Exeter
#
#
#
# LINK NO: 65
#
# LINK : https://www.exeterpremedia.com/making-collaboration-work/
#
# TITLE : Making collaboration work - Exeter
#
#
#
# LINK NO: 66
#
# LINK NO: 67
#
# LINK : https://www.exeterpremedia.com/why-do-i-need-another-id/
#
# TITLE : Why do I need another ID? - Exeter
#
#
#
# LINK NO: 68
#
# LINK : https://www.exeterpremedia.com/2018/04/
#
# TITLE : April 2018 - Exeter
#
#
#
# LINK NO: 69
#
# LINK : https://www.exeterpremedia.com/why-do-i-need-another-id/
#
# TITLE : Why do I need another ID? - Exeter
#
#
#
# LINK NO: 70
#
# LINK NO: 71
#
# LINK : https://www.exeterpremedia.com/the-death-of-the-pdf/
#
# TITLE : The Death of the PDF? - Exeter
#
#
#
# LINK NO: 72
#
# LINK : https://www.exeterpremedia.com/2018/02/
#
# TITLE : February 2018 - Exeter
#
#
#
# LINK NO: 73
#
# LINK : https://www.exeterpremedia.com/the-death-of-the-pdf/
#
# TITLE : The Death of the PDF? - Exeter
#
#
#
# LINK NO: 74
#
# LINK NO: 75
#
# LINK : https://www.linkedin.com/in/parivalavan-manoharan/
#
# TITLE : N/A
#
#
#
# LINK NO: 76
#
# LINK : https://www.linkedin.com/in/jaishankarn/
#
# TITLE : N/A
#
#
#
# LINK NO: 77
#
# LINK : https://www.linkedin.com/in/augustine-k/
#
# TITLE : N/A
#
#
#
# LINK NO: 78
#
# LINK : https://www.linkedin.com/feed/hashtag/?keywords=%23ExeterPremedia
#
# TITLE : Sign Up | LinkedIn
#
#
#
# LINK NO: 79
#
# LINK : https://www.linkedin.com/feed/hashtag/?keywords=%23Exeter
#
# TITLE : Sign Up | LinkedIn
#
#
#
# LINK NO: 80
#
# LINK : https://www.linkedin.com/feed/hashtag/?keywords=%23Kriya
#
# TITLE : Sign Up | LinkedIn
#
#
#
# LINK NO: 81
#
# LINK : https://www.linkedin.com/feed/hashtag/?keywords=%23HappyAuthors
#
# TITLE : Sign Up | LinkedIn
#
#
#
# LINK NO: 82
#
# LINK : https://www.linkedin.com/feed/hashtag/?keywords=%23SVCE
#
# TITLE : Sign Up | LinkedIn
#
#
#
# LINK NO: 83
#
# LINK : https://www.linkedin.com/feed/hashtag/?keywords=%23YetAnotherHackathon
# TITLE : Sign Up | LinkedIn
#
#
#
# LINK NO: 84
#
# LINK : https://www.linkedin.com/feed/hashtag/?keywords=%23YAH
#
# TITLE : Sign Up | LinkedIn
#
#
#
# LINK NO: 85
#
# LINK : https://www.linkedin.com/feed/hashtag/?keywords=%23Acmsvce
#
# TITLE : Sign Up | LinkedIn
#
#
#
# LINK NO: 86
#
# LINK : https://www.linkedin.com/feed/hashtag/?keywords=%23FrankfurtBookFair2019
#
# TITLE : Sign Up | LinkedIn
#
#
#
# LINK NO: 87
#
# LINK : https://www.linkedin.com/feed/hashtag/?keywords=%23ExeterPremedia
#
# TITLE : Sign Up | LinkedIn
#
#
#
# LINK NO: 88
#
# LINK : https://www.linkedin.com/feed/hashtag/?keywords=%23Kriya
#
# TITLE : Sign Up | LinkedIn
#
#
#
# LINK NO: 89
#
# LINK : https://www.linkedin.com/feed/hashtag/?keywords=%23HappyAuthors
#
# TITLE : Sign Up | LinkedIn
#
#
#
# LINK NO: 90
#
# LINK : https://www.linkedin.com/feed/hashtag/?keywords=%23CloudPublishing""
#
# TITLE : Sign Up | LinkedIn
#
#
#
# LINK NO: 91
#
# LINK : https://www.linkedin.com/feed/hashtag/?keywords=%23Epublishing
#
# TITLE : Sign Up | LinkedIn
#
#
#
# LINK NO: 92
#
# LINK : https://www.linkedin.com/feed/hashtag/?keywords=%23DigitalSolution
#
# TITLE : Sign Up | LinkedIn
#
#
#
# LINK NO: 93
#
# LINK : https://www.linkedin.com/feed/hashtag/?keywords=%23AcademicPublishing
#
# TITLE : Sign Up | LinkedIn
#
#
#
# LINK NO: 94
#
# LINK : https://www.linkedin.com/feed/hashtag/?keywords=%23ScholarlyPublishing
#
# TITLE : Sign Up | LinkedIn
#
#
#
# LINK NO: 95
#
# LINK : https://www.linkedin.com/feed/hashtag/?keywords=%23Books
#
# TITLE : Sign Up | LinkedIn
#
#
#
# LINK NO: 96
#
# LINK : https://www.linkedin.com/feed/hashtag/?keywords=%23Journals
#
# TITLE : Sign Up | LinkedIn
#
#
#
# LINK NO: 97
#
# LINK : https://www.linkedin.com/feed/hashtag/?keywords=%23PublishingServices
#
# TITLE : Sign Up | LinkedIn
#
#
#
# LINK NO: 98
#
# LINK : https://www.linkedin.com/feed/hashtag/?keywords=%23AutomationPlatform
#
# TITLE : Sign Up | LinkedIn
#
#
#
# LINK NO: 99
#
# LINK : https://www.linkedin.com/feed/hashtag/?keywords=%23Fbf19
#
# TITLE : Sign Up | LinkedIn
#
#
#
# LINK NO: 100
#
# LINK : https://www.linkedin.com/feed/hashtag/?keywords=%23Markup
#
# TITLE : Sign Up | LinkedIn
#
#
#
# LINK NO: 101
#
# LINK : https://www.linkedin.com/feed/hashtag/?keywords=%23MarkupUK2019
#
# TITLE : Sign Up | LinkedIn
#
#
#
# LINK NO: 102
#
# LINK : https://www.linkedin.com/feed/hashtag/?keywords=%23Exeter
#
# TITLE : Sign Up | LinkedIn
#
#
#
# LINK NO: 103
#
# LINK : https://www.linkedin.com/in/ravi-venkataramani-8558534/
#
# TITLE : N/A
#
#
#
# LINK NO: 104
#
# LINK : https://www.linkedin.com/company/markup-uk/
#
# TITLE : N/A
#
#
#
# LINK NO: 105
#
# LINK : https://www.linkedin.com/company/2081042/admin/
#
# TITLE : N/A
#
#
#
# LINK NO: 106
#
# LINK : https://www.exeterpremedia.com
#
# TITLE : Exeter - Happy Authors and Delighted Publishers
#
#
#
# LINK NO: 107
#
# LINK : https://www.exeterpremedia.com/services/
#
# TITLE : Exeter - Services
#
#
#
# LINK NO: 108
#
# LINK : https://www.exeterpremedia.com/client/
#
# TITLE : Client - Exeter
#
#
#
# LINK NO: 109
#
# LINK : https://www.exeterpremedia.com/blog/
#
# TITLE : Exeter - Blog
#
#
#
# LINK NO: 110
#
# LINK : https://careers.exeterpremedia.com/jobs/Careers
#
# TITLE : Jobs at Careers
#
#
#
# LINK NO: 111
#
# LINK : https://www.exeterpremedia.com/about-us/
#
# TITLE : Exeter - All about authors and publishers
#
#
#
# LINK NO: 112
#
# LINK : https://www.exeterpremedia.com/news/
#
# TITLE : Exeter - News
#
#
#
# LINK NO: 113
#
# LINK : https://www.exeterpremedia.com/events/
#
# TITLE : Exeter - Events
#
#
#
# LINK NO: 114
#
# LINK : https://www.exeterpremedia.com/contact-us/
#
# TITLE : Exeter - Contact Us
#
#
#
# LINK NO: 115
#
# LINK : https://www.exeterpremedia.com/exeter-privacy-policy/
#
# TITLE : Exeter - Privacy Policy - Exeter
#
#
#
# LINK NO: 116
#
# LINK : https://www.exeterpremedia.com/terms-and-conditions/
#
# TITLE : Terms and Conditions - Exeter
#
#
#
# LINK NO: 117
#
# LINK NO: 118
#
# LINK NO: 119
#
# LINK NO: 120
#
# LINK NO: 121
#
# LINK : https://twitter.com/Exeter_Premedia
#
# TITLE : N/A
#
#
#
# LINK NO: 122
#
# LINK : https://www.linkedin.com/company/exeter-premedia-services
#
# TITLE : N/A
#
#
#
# LINK NO: 123
#
# LINK : https://www.facebook.com/exeterpremediaservices
#
# TITLE : Exeter Premedia - வணிக மையம் - சென்னை, இந்தியா | Facebook - 59 படங்கள்
#
#
#
# LINK NO: 124
#
# LINK : https://www.instagram.com/exeterpremedia/
#
# TITLE :
# Exeter Premedia's (@exeterpremedia) Instagram profile • 18 photos and videos
#
#
#
#
# LINK NO: 125
#
# LINK NO: 126
#
# =========================================================================
#
# || SUCCESSFULLY GENERATED ALL THE POSSIBLE LINKS AND THEIR TITLES!! ||
#
# ======================================================================

# %%
#Getting the Meta Data for Home Page

meta_data_home = []
meta_data_home = urlpass.meta_find(proper_url)

# %%
#Converting the List to set() to eliminate repeated links
valid_links_set = set(valid_links)


#Converting the valid_links back to list() to loop through it
valid_links = list(valid_links_set)

# %%
#Getting the number of valid links
valid_no = len(valid_links)

#Getting the number of invalid links
invalid_no = total_no - valid_no

# %%
#Collecting the details like Titles, Internal or External Links

#Declaring bools to check if a link is Internal or External which will be used in dataFrame
internal_bool = []
external_bool = []


for link in valid_links:
    print(f"\n Getting Title and Internal & External Links of {link}")
    
    #Getting Title of all the valid Links
    title = urlpass.title(link)
    title_names.append(title)
    
    
    #Segregating the valid links into Internal and External links 
    if domain_name in link:
        internal_links.append(link)
        internal_bool.append("True")
        external_bool.append("False")
        
        
    else:
        external_links.append(link)
        internal_bool.append("False")
        external_bool.append("True")
    
    #Clearing the output after each iteration to improve the readability
    clear_output(wait=True)
    
print(" \n=========================================================================")
print(f"\n|| SUCCESSFULLY COLLECTED ALL THE NECESSARY DETAILS!! ||\n")
print("======================================================================\n")
# Out:
#
# =========================================================================
#
# || SUCCESSFULLY COLLECTED ALL THE NECESSARY DETAILS!! ||
#
# ======================================================================

# %%
#Writing the valid links into the "Valid_Links.txt" file in the "Home" Directory

with open("/Users/sk/Desktop/Challenge/Home/Valid_Links.txt", mode = "w") as val:
    val.write(f"ALL THE VALID LINKS IN {domain_name}\n")
    for link in valid_links:
        val.write(f"\n\n{link}\n\n#########################################################################################\n\n")

# %%
#Writing the Titles into the "Titles.txt" file in the "Home" Directory

with open("/Users/sk/Desktop/Challenge/Home/Titles.txt", mode = "w") as val:
    val.write(f"ALL THE TITLE OF THE VALID LINKS IN {domain_name}\n")
    for link in title_names:
        val.write(f"\n\n{link}\n\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%\n\n")

# %%
#Writing the Internal Links into the "Internal_links.txt" file in the "Home" Directory

with open("/Users/sk/Desktop/Challenge/Home/Internal_links.txt", mode = "w") as val:
    val.write(f"THE INTERNAL LINKS IN THE VALID LINKS IN {domain_name}")
    for link in internal_links:
        val.write(f"\n\n{link}\n\n------------------------------------------------------------------------------------------\n\n")

# %%
#Writing the External Links into the "External_links.txt" file in the "Home" Directory


with open("/Users/sk/Desktop/Challenge/Home/External_links.txt", mode = "w") as val:
    val.write(f"THE EXTERNAL LINKS IN THE VALID LINKS IN {domain_name}")
    for link in external_links:
        val.write(f"\n\n{link}\n\n==========================================================================================\n\n")

# %%
#Writing the Meta Data in the Home Page into the "Meta_Data.txt"  in the "Home" Directory

with open("/Users/sk/Desktop/Challenge/Home/Meta_Data.txt", mode = "w") as val:
    val.write(f"THE META DATA IN THE VALID LINKS IN {domain_name}")
    for link in meta_data_home:
        val.write(f"\n\n{link}\n\n==========================================================================================\n\n")

# %%
#Getting the number of Internal Links and External Links


internal_num = len(internal_links)
external_num = len(external_links)

# %%
print(" \n=========================================")
print(f"\n|| Total Number of Links: {total_no} ||\n")
print("=========================================")


print(" \n=========================================")
print(f"\n|| Total Number of Valid Links: {valid_no} ||\n")
print("=========================================")


print(" \n=========================================")
print(f"\n|| Total Number of Invalid Links: {invalid_no} ||\n")
print("=========================================")


print(" \n=========================================")
print(f"\n|| Total Number of Internal Links is {internal_num} ||\n")
print("=========================================")


print(" \n==========================================")
print(f"\n|| Total Number of External Links is {external_num} ||\n")
print("==========================================")


with open(f"/Users/sk/Desktop/Challenge/Numbers/Number_links.txt", mode = "w") as val:
        val.write(f"\nTOTAL NUMBER OF LINKS IN {proper_url}\n\n")
        val.write(f"\n\n{total_no}\n\n----------------------------\n\n")
        
        
with open(f"/Users/sk/Desktop/Challenge/Numbers/Number_links.txt", mode = "a") as val:
        val.write(f"\nTOTAL NUMBER OF VALID LINKS IN {proper_url}\n\n")
        val.write(f"\n\n{valid_no}\n\n----------------------------\n\n")


with open(f"/Users/sk/Desktop/Challenge/Numbers/Number_links.txt", mode = "a") as val:
        val.write(f"\nTOTAL NUMBER OF INVALID LINKS IN {proper_url}\n\n")
        val.write(f"\n\n{invalid_no}\n\n----------------------------\n\n")


        
with open(f"/Users/sk/Desktop/Challenge/Numbers/Number_links.txt", mode = "a") as val:
        val.write(f"\nTOTAL NUMBER OF INTERNAL LINKS IN {proper_url}\n\n")
        val.write(f"\n\n{internal_num}\n\n----------------------------\n\n")


        
with open(f"/Users/sk/Desktop/Challenge/Numbers/Number_links.txt", mode = "a") as val:
        val.write(f"\nTOTAL NUMBER OF EXTERNAL LINKS IN {proper_url}\n\n")
        val.write(f"\n\n{external_num}\n\n----------------------------\n\n")
# Out:
#
# =========================================
#
# || Total Number of Links: 126 ||
#
# =========================================
#
# =========================================
#
# || Total Number of Valid Links: 85 ||
#
# =========================================
#
# =========================================
#
# || Total Number of Invalid Links: 41 ||
#
# =========================================
#
# =========================================
#
# || Total Number of Internal Links is 51 ||
#
# =========================================
#
# ==========================================
#
# || Total Number of External Links is 34 ||
#
# ==========================================

# %%
z = 1
top20_uni = []
top20_bi = []
#Iterating through the valid links

for link in valid_links:
    
    print(f"\n Getting Raw Data, Unigrams and Bigrams from {link}")
    
    
    #Getting the raw_text, unigrams and bigrams from the valid links
    raw_text, text_len, unigrams_text_links, bigrams_text_links = urlpass.get_text_from_web(link)
    
    unigram_lst.append(unigrams_text_links)
    bigram_lst.append(bigrams_text_links)
    
    #Getting the Meta Data for every valid link
    meta_data_links = urlpass.meta_find(link)
    
    #Writing the Raw Data of the links 

    with open(f"/Users/sk/Desktop/Challenge/Raw_Data/{z}_Data.txt", mode = "w") as val:
        val.write(f"THE RAW DATA IN THE LINK, {link}")
        for x in raw_text:
            val.write(f"\n\n{x}\n\n----------------------------\n\n")
    
    #Writing the Meta data of the links 
    
    with open(f"/Users/sk/Desktop/Challenge/Meta_Data/{z}_Meta_Data.txt", mode = "w") as val:
        val.write(f"THE META DATA IN THE LINK, {link}")
        for x in meta_data_links:
            val.write(f"\n\n{x}\n\n----------------------------\n\n")
            
    #Writing the Unigrams of the links 
    
    with open(f"/Users/sk/Desktop/Challenge/Unigrams/{z}_Unigrams.txt", mode = "w") as val:
        val.write(f"THE UNIGRAMS IN THE LINK, {link}")
        for x in unigrams_text_links:
            val.write(f"\n\n{x}\n\n-----------------------------\n\n")
            
    #Writing the Bigrams of the links 
    
    with open(f"/Users/sk/Desktop/Challenge/Bigrams/{z}_Bigrams.txt", mode = "w") as val:
        val.write(f"THE BIGRAMS IN THE LINK, {link}")
        for x in bigrams_text_links:
            val.write(f"\n\n{x}\n\n-----------------------------\n\n")
    
    
    #Getting the top 20 frequent unigrams and bigrams
    
    l_uni_links, l_bi_links = urlpass.frequency(unigrams_text_links, bigrams_text_links)
    
    top20_uni.append(l_uni_links)
    top20_bi.append(l_bi_links)
    
    
    #Writing the Top 20 Unigrams of the links 
    
    with open(f"/Users/sk/Desktop/Challenge/Top20Unigrams/{z}_Top20Unigrams=.txt", mode = "w") as val:
        val.write(f"THE TOP 20 UNIGRAMS IN DESCENDING ORDER, {link}")
        for x in l_uni_links:
            val.write(f"\n\n{x}\n\n=====================================\n\n")
            
    #Writing the Top 20 Bigrams of the links
    
    with open(f"/Users/sk/Desktop/Challenge/Top20Bigrams/{z}_Top20Bigrams.txt", mode = "w") as val:
        val.write(f"THE TOP 20 BIGRAMS IN DESCENDING ORDER, {link}")
        for x in l_bi_links:
            val.write(f"\n\n{x}\n\n=====================================\n\n")
    z+=1
# Out:
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/wp-content/uploads/2019/06/springer-publishing-company.webp
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/2018/04/
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/services/#Project_Management
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.linkedin.com/feed/hashtag/?keywords=%23ExeterPremedia
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/wp-content/uploads/2019/06/elife-science-publications-ltd.webp
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/wp-content/uploads/2019/06/cabi.webp
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.linkedin.com/feed/hashtag/?keywords=%23YAH
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/wp-content/uploads/2019/06/wit-press.webp
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.linkedin.com/feed/hashtag/?keywords=%23Journals
#
#  Getting Raw Data, Unigrams and Bigrams from http://www.exeterpremedia.com//services/#Data_Services
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/wp-content/uploads/2019/06/rosen-publishing.webp
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/wp-content/uploads/2019/06/the-british-small-animal-veterinary-association.webp
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.instagram.com/exeterpremedia/
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/terms-and-conditions/
#
#  Getting Raw Data, Unigrams and Bigrams from http://www.exeterpremedia.com//services/#Artwork
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/wp-content/uploads/2019/06/john-benjamins-publishing-company.webp
#
#  Getting Raw Data, Unigrams and Bigrams from http://www.exeterpremedia.com//services/#Editorial_Services
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.linkedin.com/feed/hashtag/?keywords=%23Kriya
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/2019/02/
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/wp-content/uploads/2019/06/bolinda-publishing-llc.webp
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.linkedin.com/feed/hashtag/?keywords=%23ScholarlyPublishing
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/wp-content/uploads/2019/06/bsi-group.webp
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.linkedin.com/feed/hashtag/?keywords=%23Markup
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/contact-us/
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/wp-content/uploads/2019/06/walter-de-gruyter-gmbh-co.-kg.webp
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/news/
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/wp-content/uploads/2019/06/brill.webp
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.linkedin.com/company/2081042/admin/
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/wp-content/uploads/2019/06/taylor-and-francis.webp
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.linkedin.com/feed/hashtag/?keywords=%23Books
#
#  Getting Raw Data, Unigrams and Bigrams from http://www.exeterpremedia.com//services/#Project_Management
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/wp-content/uploads/2019/06/stylus-publishing-llc.webp
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.linkedin.com/feed/hashtag/?keywords=%23Epublishing
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/exeter-privacy-policy/
#
#  Getting Raw Data, Unigrams and Bigrams from http://twitter.com//statuses/
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/wp-content/uploads/2019/06/summer-game-books.webp
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/wp-content/uploads/2019/06/royal-college-of-general-practitioners.webp
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.linkedin.com/company/exeter-premedia-services
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/wp-content/uploads/2019/06/british-institute-of-radiology.webp
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.linkedin.com/feed/hashtag/?keywords=%23Acmsvce
#
#  Getting Raw Data, Unigrams and Bigrams from https://twitter.com/Exeter_Premedia
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.linkedin.com/feed/hashtag/?keywords=%23AutomationPlatform
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/services/#Data_Services
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.linkedin.com/company/markup-uk/
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/blog/
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.linkedin.com/in/ravi-venkataramani-8558534/
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/wp-content/uploads/2019/06/the-british-editorial-society-of-bone-joint-surgery.webp
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/wp-content/uploads/2019/06/bmj-group.webp
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/wp-content/uploads/2019/06/atma-global-inc.webp
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/about-us/
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/why-do-i-need-another-id/
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.linkedin.com/in/augustine-k/
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.linkedin.com/feed/hashtag/?keywords=%23HappyAuthors
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/wp-content/uploads/2019/06/journal-of-royal-medical-service.webp
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/the-death-of-the-pdf/
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/events/
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.linkedin.com/feed/hashtag/?keywords=%23DigitalSolution
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.linkedin.com/feed/hashtag/?keywords=%23AcademicPublishing
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.linkedin.com/feed/hashtag/?keywords=%23Exeter
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/wp-content/uploads/2019/06/sage-publishing.webp
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.linkedin.com/feed/hashtag/?keywords=%23Fbf19
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/services/
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.linkedin.com/feed/hashtag/?keywords=%23MarkupUK2019
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.linkedin.com/feed/hashtag/?keywords=%23SVCE
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.linkedin.com/feed/hashtag/?keywords=%23FrankfurtBookFair2019
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.linkedin.com/in/parivalavan-manoharan/
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/wp-content/uploads/2019/06/paths-international.webp
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/services/#Artwork
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/services/#Editorial_Services
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/2018/02/
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.facebook.com/exeterpremediaservices
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/client/
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/wp-content/uploads/2019/06/royal-college-of-surgeons.webp
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.linkedin.com/feed/hashtag/?keywords=%23PublishingServices
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/wp-content/uploads/2019/06/business-expert-press.webp
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.linkedin.com/feed/hashtag/?keywords=%23CloudPublishing""
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.linkedin.com/feed/hashtag/?keywords=%23YetAnotherHackathon
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/making-collaboration-work/
#
#  Getting Raw Data, Unigrams and Bigrams from https://careers.exeterpremedia.com/jobs/Careers
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.linkedin.com/in/jaishankarn/
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/wp-content/uploads/2019/06/microbiology-society.webp
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.exeterpremedia.com/wp-content/uploads/2019/06/momentum-press.webp
#
#  Getting Raw Data, Unigrams and Bigrams from https://www.kriyadocs.com/

# %%
#Repeating the same process for the Home Page

raw_text, text_len, unigrams_text_home, bigrams_text_home = urlpass.get_text_from_web(proper_url)
    
with open(f"/Users/sk/Desktop/Challenge/Home/Home_Data.txt", mode = "w") as val:
    val.write(f"THE RAW DATA IN THE LINK, {proper_url}")
    for x in raw_text:
        val.write(f"\n\n{x}\n\n----------------------------\n\n")
            
    
with open(f"/Users/sk/Desktop/Challenge/Home/Home_Unigrams.txt", mode = "w") as val:
    val.write(f"THE UNIGRAMS IN THE LINK, {proper_url}")
    for x in unigrams_text_home:
        val.write(f"\n\n{x}\n\n-----------------------------\n\n")
            
    
with open(f"/Users/sk/Desktop/Challenge/Home/Home_Bigrams.txt", mode = "w") as val:
    val.write(f"THE BIGRAMS IN THE LINK, {proper_url}")
    for x in bigrams_text_home:
        val.write(f"\n\n{x}\n\n-----------------------------\n\n")
    
    
l_uni_home, l_bi_home = urlpass.frequency(unigrams_text_home, bigrams_text_home)
    
    
with open(f"/Users/sk/Desktop/Challenge/Home/Home_Top20Unigrams=.txt", mode = "w") as val:
    val.write(f"THE TOP 20 UNIGRAMS IN DESCENDING ORDER, {proper_url}")
    for x in l_uni_home:
        val.write(f"\n\n{x}\n\n=====================================\n\n")
            
            
with open(f"/Users/sk/Desktop/Challenge/Home/Home_Top20Bigrams.txt", mode = "w") as val:
    val.write(f"THE TOP 20 BIGRAMS IN DESCENDING ORDER, {proper_url}")
    for x in l_bi_home:
        val.write(f"\n\n{x}\n\n=====================================\n\n")

# %%
#Getting the size of the home page using urlpass.pagesize() in urlmate
check_size, size_bytes, size_kb = urlpass.pagesize(proper_url)

with open("/Users/sk/Desktop/Challenge/Size/File_Size.txt", mode = "w") as val:
    val.write(f" \n==========================================================================================\n||The size of {proper_url} in Bytes is {size_bytes} Bytes ||\n==========================================================================================\n")
    val.write(f" \n==========================================================================================\n||The size of {proper_url}in KB is {size_kb:1.2f} KB's ||\n==========================================================================================\n")

# %%
#Getting the size of all the valid links using urlpass.pagesize() in urlmate

size_kb_links = []

for link in valid_links:
    
    check_size, size_bytes, size_kb = urlpass.pagesize(link)
    size_kb_links.append(round(size_kb, 2))
    
    with open("/Users/sk/Desktop/Challenge/Size/File_Size.txt", mode = "a") as val:
        val.write(f" \n==========================================================================================\n||The size of {link} in Bytes is {size_bytes} Bytes ||\n=========================================================================================\n")
        val.write(f" \n==========================================================================================\n||The size of {link}in KB is {size_kb:1.2f} KB's ||\n===========================================================================================\n")

# %%
for i in range(valid_no):
    
    storage_dict[i] = [valid_links[i], title_names[i], internal_bool[i], external_bool[i], top20_uni[i], top20_bi[i], size_kb_links[i]]

# %%
storage_df = pd.DataFrame.from_dict(storage_dict, orient='index', columns=['VALID LINKS','TITLE NAMES','INTERNAL LINK','EXTERNAL LINK', 'TOP20 UNI', 'TOP20 BI', 'WEB PAGE SIZE (KB)'])

# %%
storage_df.to_csv("/Users/sk/Desktop/Challenge/CSV/Exeter_Data.csv")

# %%
storage_df.head(17)
# Out:
#                                           VALID LINKS  \
# 0   https://www.exeterpremedia.com/wp-content/uplo...
# 1             https://www.exeterpremedia.com/2018/04/
# 2   https://www.exeterpremedia.com/services/#Proje...
# 3   https://www.linkedin.com/feed/hashtag/?keyword...
# 4   https://www.exeterpremedia.com/wp-content/uplo...
# 5   https://www.exeterpremedia.com/wp-content/uplo...
# 6   https://www.linkedin.com/feed/hashtag/?keyword...
# 7   https://www.exeterpremedia.com/wp-content/uplo...
# 8   https://www.linkedin.com/feed/hashtag/?keyword...
# 9   http://www.exeterpremedia.com//services/#Data_...
# 10  https://www.exeterpremedia.com/wp-content/uplo...
# 11  https://www.exeterpremedia.com/wp-content/uplo...
# 12          https://www.instagram.com/exeterpremedia/
# 13                    https://www.exeterpremedia.com/
# 14  https://www.exeterpremedia.com/terms-and-condi...
# 15   http://www.exeterpremedia.com//services/#Artwork
# 16  https://www.exeterpremedia.com/wp-content/uplo...
#
#                                           TITLE NAMES INTERNAL LINK  \
# 0                                                 N/A          True
# 1                                 April 2018 - Exeter          True
# 2                                   Exeter - Services          True
# 3                                  Sign Up | LinkedIn         False
# 4                                                 N/A          True
# 5                                                 N/A          True
# 6                                  Sign Up | LinkedIn         False
# 7                                                 N/A          True
# 8                                  Sign Up | LinkedIn         False
# 9                                   Exeter - Services          True
# 10                                                N/A          True
# 11                                                N/A          True
# 12  \nExeter Premedia's (@exeterpremedia) Instagra...         False
# 13    Exeter - Happy Authors and Delighted Publishers          True
# 14                      Terms and Conditions - Exeter          True
# 15                                  Exeter - Services          True
# 16                                                N/A          True
#
#    EXTERNAL LINK                                          TOP20 UNI  \
# 0          False                                             [NULL]
# 1          False  [US, SERVICES, April, Us, us, About, India, Co...
# 2          False  [services, Services, We, publishers, Design, O...
# 3           True  [LinkedIn, Chinese, Policy, Agree, Sign, Tradi...
# 4          False                                             [NULL]
# 5          False                                             [NULL]
# 6           True  [LinkedIn, Chinese, Policy, Agree, Sign, Tradi...
# 7          False                                             [NULL]
# 8           True  [LinkedIn, Chinese, Policy, Agree, Sign, Tradi...
# 9          False  [services, Services, We, publishers, Design, O...
# 10         False                                             [NULL]
# 11         False                                             [NULL]
# 12          True  [videos, photos, 18, profile, Instagram, exete...
# 13         False  [Exeter, Premedia, Service, Kriya, us, Happy, ...
# 14         False  [Services, Terms, use, us, Party, You, may, We...
# 15         False  [services, Services, We, publishers, Design, O...
# 16         False                                             [NULL]
#
#                                              TOP20 BI  WEB PAGE SIZE (KB)
# 0                                              [NULL]                6.48
# 1   [(Contact, Us), (US, careers), (CONTACT, US), ...              110.20
# 2   [(Artwork, Design), (Project, Management), (Da...              127.01
# 3   [(Chinese, TraditionalLanguage), (Simplified正體...               24.43
# 4                                              [NULL]                9.71
# 5                                              [NULL]                7.16
# 6   [(Chinese, TraditionalLanguage), (Simplified正體...               24.34
# 7                                              [NULL]               10.73
# 8   [(Chinese, TraditionalLanguage), (Simplified正體...               24.39
# 9   [(Artwork, Design), (Project, Management), (Da...              126.92
# 10                                             [NULL]                9.48
# 11                                             [NULL]               18.36
# 12  [(photos, videos), (18, photos), (profile, 18)...              116.73
# 13  [(Exeter, Premedia), (Service, Exeter), (Preme...              157.70
# 14  [(Confidential, Information), (Receiving, Part...              124.35
# 15  [(Artwork, Design), (Project, Management), (Da...              126.92
# 16                                             [NULL]               13.01

# %%
storage_df.tail()
# Out:
#                                           VALID LINKS       TITLE NAMES  \
# 80    https://careers.exeterpremedia.com/jobs/Careers   Jobs at Careers
# 81           https://www.linkedin.com/in/jaishankarn/               N/A
# 82  https://www.exeterpremedia.com/wp-content/uplo...               N/A
# 83  https://www.exeterpremedia.com/wp-content/uplo...               N/A
# 84                         https://www.kriyadocs.com/  Home - Kriyadocs
#
#    INTERNAL LINK EXTERNAL LINK  \
# 80         False          True
# 81         False          True
# 82          True         False
# 83          True         False
# 84         False          True
#
#                                             TOP20 UNI  \
# 80                                    [Careers, Jobs]
# 81                                                 []
# 82                                             [NULL]
# 83                                             [NULL]
# 84  [kriyadocs, content, Your, PDF, get, need, I, ...
#
#                                              TOP20 BI  WEB PAGE SIZE (KB)
# 80                                  [(Jobs, Careers)]               21.66
# 81                                                 []                0.00
# 82                                             [NULL]               13.98
# 83                                             [NULL]               15.12
# 84  [(Schedule, Demo), (required, Your), (Contact,...               99.08
